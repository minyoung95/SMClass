# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 한글 설정
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Window용
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac 용
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 그래프 마이너스까지 나타낼 수 있게

df = pd.read_csv('chipotle.tsv',sep='\t')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df_bar = df.groupby('item_name')['order_id'].count().head(5)
df_bar
# Out:
# item_name
# 6 Pack Soft Drink        54
# Barbacoa Bowl            66
# Barbacoa Burrito         91
# Barbacoa Crispy Tacos    11
# Barbacoa Salad Bowl      10
# Name: order_id, dtype: int64

# %%
avg = df.groupby('item_name')['order_id'].count().head(10).mean()
avg
# Out:
# np.float64(53.1)

# %%
## 메뉴별 주문갯수 5개 봅아서 막대그래프로 출력
df_bar = df.groupby('item_name')['order_id'].count().head(10)
df_bar['mean'] = df.groupby('item_name')['order_id'].count().mean()


df2_bar = plt.bar(df_bar.index,df_bar)
plt.plot(df_bar.index,[df_bar['mean']]*11,ls='--',color='red')
df2_bar[len(df_bar.index)-1].set_color('red')
plt.xticks(rotation = 90)

plt.show()
