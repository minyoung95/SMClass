# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 한글 설정
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Window용
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac 용
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 그래프 마이너스까지 나타낼 수 있게

# %%
df = pd.read_excel('출산율02.xlsx',skiprows=2,nrows=2,index_col=0)
df
# Out:
# c:\python\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#            2014     2015     2016     2017     2018     2019     2020  \
# 출생아 수   435.400  438.400  406.200  357.800  326.800  302.700  272.300
# 합계 출산율    1.205    1.239    1.172    1.052    0.977    0.918    0.837
#
#            2021    2022    2023
# 출생아 수   260.600  249.10  230.00
# 합계 출산율    0.808    0.78    0.72

# %%
df.columns
df.values
df.index.values
df.rename(index={'출생아\xa0수':'출생아 수','합계\xa0출산율':'합계 출산율'},inplace=True)
df
# Out:
#            2014     2015     2016     2017     2018     2019     2020  \
# 출생아 수   435.400  438.400  406.200  357.800  326.800  302.700  272.300
# 합계 출산율    1.205    1.239    1.172    1.052    0.977    0.918    0.837
#
#            2021    2022    2023
# 출생아 수   260.600  249.10  230.00
# 합계 출산율    0.808    0.78    0.72

# %%
df.index.values
# Out:
# array(['출생아 수', '합계 출산율'], dtype=object)

# %%
plt.figure(figsize=(20,5))
fig,axs = plt.subplots(2,1,figsize=(15,13))
axs[0].plot(df.columns,df.loc['출생아 수'],marker='o',markerfacecolor='white')
for i in range(10):
    axs[0].text(df.columns[i],df.loc['출생아 수'][i]+2,df.loc['출생아 수'][i],ha='center')
# axs[1].plot(df.columns,df.loc['합계 출산율'],marker='o',markerfacecolor='white')
# for i in range(10):
#     axs[1].text(df.columns[i],df.loc['합계 출산율'][i]+2,df.loc['합계 출산율'][i],ha='center')
# Out:
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_9700\1839103006.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   axs[0].text(df.columns[i],df.loc['출생아 수'][i]+2,df.loc['출생아 수'][i],ha='center')
